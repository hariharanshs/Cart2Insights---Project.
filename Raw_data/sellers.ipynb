# %%
import pandas as pd

# %%
sell = pd.read_csv(r"C:\Users\Administrator\Documents\1st Project\Raw_data\olist_sellers_dataset.csv")

# %%
sell.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
sell.columns
# Out:
# Index(['seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state'], dtype='str')

# %%
sell.shape
# Out:
# (3095, 4)

# %%
sell.dtypes
# Out:
# seller_id                   str
# seller_zip_code_prefix    int64
# seller_city                 str
# seller_state                str
# dtype: object

# %%
sell.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
sell.duplicated().sum()
# Out:
# np.int64(0)

# %%
sell['seller_state'].unique()
# Out:
# <StringArray>
# ['SP', 'RJ', 'PE', 'PR', 'GO', 'SC', 'BA', 'DF', 'RS', 'MG', 'RN', 'MT', 'CE',
#  'PB', 'AC', 'ES', 'RO', 'PI', 'MS', 'SE', 'MA', 'AM', 'PA']
# Length: 23, dtype: str

# %%
sell['seller_city'].nunique()
# Out:
# 611

# %%
sell['seller_id'].is_unique
# Out:
# True

# %%
sell['seller_city'] = sell['seller_city'].str.lower().str.strip()

# %%
sell['seller_state'] = sell['seller_state'].str.upper().str.strip()

# %%
sell.to_csv(r"C:\Users\Administrator\Documents\1st Project\Processed_data\sellers_clean.csv", index=False)
