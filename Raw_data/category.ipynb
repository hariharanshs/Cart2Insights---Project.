# %%
import pandas as pd

# %%
cat = pd.read_csv(r"C:\Users\Administrator\Documents\1st Project\Raw_data\product_category_name_translation.csv")

# %%
cat.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
cat.shape
# Out:
# (71, 2)

# %%
cat.columns
# Out:
# Index(['product_category_name', 'product_category_name_english'], dtype='str')

# %%
cat.dtypes
# Out:
# product_category_name            str
# product_category_name_english    str
# dtype: object

# %%
cat.isnull().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
cat.duplicated().sum()
# Out:
# np.int64(0)

# %%
cat['product_category_name'].is_unique
# Out:
# True

# %%
cat['product_category_name'].nunique()
# Out:
# 71

# %%
cat['product_category_name_english'].nunique()
# Out:
# 71

# %%
cat.to_csv(r"C:\Users\Administrator\Documents\1st Project\Processed_data\category_translation_clean.csv", index=False)
