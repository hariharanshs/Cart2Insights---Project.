# %%
import pandas as pd

# %%
orderp = pd.read_csv(r"C:\Users\Administrator\Documents\1st Project\Raw_data\olist_order_payments_dataset.csv")

# %%
orderp.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
orderp.shape
# Out:
# (103886, 5)

# %%
orderp.columns
# Out:
# Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value'],
#       dtype='str')

# %%
orderp.dtypes
# Out:
# order_id                    str
# payment_sequential        int64
# payment_type                str
# payment_installments      int64
# payment_value           float64
# dtype: object

# %%
orderp.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
orderp.duplicated().sum()
# Out:
# np.int64(0)

# %%
orderp["payment_type"].unique()
# Out:
# <StringArray>
# ['credit_card', 'boleto', 'voucher', 'debit_card', 'not_defined']
# Length: 5, dtype: str

# %%
orderp["payment_installments"].describe()
# Out:
# count    103886.000000
# mean          2.853349
# std           2.687051
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           4.000000
# max          24.000000
# Name: payment_installments, dtype: float64

# %%
orderp["payment_value"].describe()
# Out:
# count    103886.000000
# mean        154.100380
# std         217.494064
# min           0.000000
# 25%          56.790000
# 50%         100.000000
# 75%         171.837500
# max       13664.080000
# Name: payment_value, dtype: float64

# %%
orderp['payment_type'].value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %%
orderp["payment_installments"].value_counts()
# Out:
# payment_installments
# 1     52546
# 2     12413
# 3     10461
# 4      7098
# 10     5328
# 5      5239
# 8      4268
# 6      3920
# 7      1626
# 9       644
# 12      133
# 15       74
# 18       27
# 11       23
# 24       18
# 20       17
# 13       16
# 14       15
# 17        8
# 16        5
# 21        3
# 0         2
# 22        1
# 23        1
# Name: count, dtype: int64

# %%
orderp[orderp['payment_installments'] == 0]
# Out:
#                                order_id  payment_sequential payment_type  \
# 46982  744bade1fcf9ff3f31d860ace076d422                   2  credit_card
# 79014  1a57108394169c0b47d8f876acc9ba2d                   2  credit_card
#
#        payment_installments  payment_value
# 46982                     0          58.69
# 79014                     0         129.94

# %%
orderp['payment_installments'] = orderp['payment_installments'].replace(0, 1)

# %%
orderp['payment_installments'].describe()
# Out:
# count    103886.000000
# mean          2.853368
# std           2.687034
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           4.000000
# max          24.000000
# Name: payment_installments, dtype: float64

# %%
orderp['payment_value'].describe()
# Out:
# count    103886.000000
# mean        154.100380
# std         217.494064
# min           0.000000
# 25%          56.790000
# 50%         100.000000
# 75%         171.837500
# max       13664.080000
# Name: payment_value, dtype: float64

# %%
orderp[orderp['payment_value'] == 0]
# Out:
#                                 order_id  payment_sequential payment_type  \
# 19922   8bcbe01d44d147f901cd3192671144db                   4      voucher
# 36822   fa65dad1b0e818e3ccc5cb0e39231352                  14      voucher
# 43744   6ccb433e00daae1283ccc956189c82ae                   4      voucher
# 51280   4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 57411   00b1cb0320190ca0daa2c88b35206009                   1  not_defined
# 62674   45ed6e85398a87c253db47c2d9f48216                   3      voucher
# 77885   fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
# 94427   c8c528189310eaa44a745b8d9d26908b                   1  not_defined
# 100766  b23878b3e8eb4d25a158f57d96331b18                   4      voucher
#
#         payment_installments  payment_value
# 19922                      1            0.0
# 36822                      1            0.0
# 43744                      1            0.0
# 51280                      1            0.0
# ...

# %%
Q1 = orderp['payment_value'].quantile(0.25)
Q3 = orderp['payment_value'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR

high_payment_count = (orderp['payment_value'] > upper_bound).sum()
print("Rows above upper bound:", high_payment_count)
# Out:
# Rows above upper bound: 7981

# %%
outliers = orderp[orderp['payment_value'] > upper_bound]
outliers.head()
# Out:
#                             order_id  payment_sequential payment_type  \
# 23  4d680edbaa7d3d9bed69532957368a03                   1  credit_card
# 26  d0a945f85ba1074b60aac97ade7e240e                   1  credit_card
# 52  2e2c60b99754ae1e4d8b18846cfec9f2                   1  credit_card
# 54  95442deb81a5d91c97c0df96b431634a                   1       boleto
# 61  3ab4eea6776259ae8dfbabaeffece352                   1  credit_card
#
#     payment_installments  payment_value
# 23                    10         353.09
# 26                     2         541.00
# 52                     4         542.66
# 54                     1         368.98
# 61                     8         387.80

# %%
orderp[['order_id', 'payment_sequential']].duplicated().sum()
# Out:
# np.int64(0)

# %%
orderp['payment_installments'] = orderp['payment_installments'].replace(0, 1)

# %%
orderp['payment_type'] = orderp['payment_type'].replace('not_defined', 'unknown')

# %%
orderp['payment_type'].unique()
# Out:
# <StringArray>
# ['credit_card', 'boleto', 'voucher', 'debit_card', 'unknown']
# Length: 5, dtype: str

# %%
orderp['payment_installments'].min()
# Out:
# np.int64(1)

# %%
orderp.to_csv(r"C:\Users\Administrator\Documents\1st Project\Processed_data\order_payments_clean.csv", index=False)
