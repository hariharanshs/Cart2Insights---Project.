# %%
import pandas as pd

# %%
customer = pd.read_csv(r'C:\Users\Administrator\Documents\1st Project\Raw_data\olist_customers_dataset.csv')

# %%
customer.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customer.shape
# Out:
# (99441, 5)

# %%
customer.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='str')

# %%
customer.dtypes
# Out:
# customer_id                   str
# customer_unique_id            str
# customer_zip_code_prefix    int64
# customer_city                 str
# customer_state                str
# dtype: object

# %%
customer.info
# Out:
# <bound method DataFrame.info of                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
# ...

# %%
customer.isnull()
# Out:
#        customer_id  customer_unique_id  customer_zip_code_prefix  \
# 0            False               False                     False
# 1            False               False                     False
# 2            False               False                     False
# 3            False               False                     False
# 4            False               False                     False
# ...            ...                 ...                       ...
# 99436        False               False                     False
# 99437        False               False                     False
# 99438        False               False                     False
# 99439        False               False                     False
# 99440        False               False                     False
#
#        customer_city  customer_state
# 0              False           False
# 1              False           False
# 2              False           False
# ...

# %%
customer.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customer.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99436    False
# 99437    False
# 99438    False
# 99439    False
# 99440    False
# Length: 99441, dtype: bool

# %%
customer.duplicated().sum()
# Out:
# np.int64(0)

# %%
customer.nunique() == len(customer)
# Out:
# customer_id                  True
# customer_unique_id          False
# customer_zip_code_prefix    False
# customer_city               False
# customer_state              False
# dtype: bool

# %%
customer['customer_state'].unique()
# Out:
# <StringArray>
# ['SP', 'SC', 'MG', 'PR', 'RJ', 'RS', 'PA', 'GO', 'ES', 'BA', 'MA', 'MS', 'CE',
#  'DF', 'RN', 'PE', 'MT', 'AM', 'AP', 'AL', 'RO', 'PB', 'TO', 'PI', 'AC', 'SE',
#  'RR']
# Length: 27, dtype: str

# %%
customer['customer_city'].nunique()
# Out:
# 4119

# %%
customer["customer_city"] = customer["customer_city"].str.lower().str.strip()

# %%
customer["customer_city"].nunique()
# Out:
# 4119

# %%
customer['customer_state'].nunique()
# Out:
# 27

# %%
customer['customer_state'] = customer['customer_state'].str.upper().str.strip()

# %%
customer['customer_state'].nunique()
# Out:
# 27

# %%
import os

# %%
print(os.getcwd())
# Out:
# c:\Users\Administrator\Documents\1st Project\Raw_data

# %%
os.makedirs(r"C:\Users\Administrator\Documents\1st Project\Processed_data", exist_ok=True)

customer.to_csv(r"C:\Users\Administrator\Documents\1st Project\Processed_data\customers_clean.csv", index=False)

# %%
customer.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
